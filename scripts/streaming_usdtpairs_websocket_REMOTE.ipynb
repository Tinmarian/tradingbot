# %%
import pandas as pd
import websocket
import json

path = 'D:/tradingbot_data/csvs/streaming/'

stream = "wss://stream.binance.com:9443/ws/btcusdt@miniTicker"

def on_message(ws, message):
    msg = json.loads(message)
    df1 = pd.DataFrame([msg])[['E','s','c']]
    df1.E = pd.to_datetime(df1.E, unit='ms')
    df1.c = df1.c.astype(float)
    for row in range(len(df1)):
        data = df1[row:row+1]
        data.to_csv(
            path_or_buf = path+data['s'].values[0]+'.csv',
            mode='a',
            index=False,
            header=False
        )
        print(data)

ws = websocket.WebSocketApp(stream, on_message=on_message)
ws.run_forever()
# Out:
#                         E        s         c
# 0 2024-04-07 12:15:48.152  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:15:49.237  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:15:50.467  BTCUSDT  69284.01
#                         E        s         c
# 0 2024-04-07 12:15:51.405  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:15:51.755  BTCUSDT  69284.01
#                         E        s         c
# 0 2024-04-07 12:15:53.198  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:15:53.943  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:15:55.483  BTCUSDT  69284.01
#                         E        s         c
# 0 2024-04-07 12:15:55.836  BTCUSDT  69284.01
#                         E        s         c
# 0 2024-04-07 12:15:57.501  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:15:58.115  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:15:59.242  BTCUSDT  69284.01
#                         E        s         c
# 0 2024-04-07 12:16:00.477  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:00.929  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:02.345  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:02.955  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:04.473  BTCUSDT  69284.01
#                         E        s         c
# 0 2024-04-07 12:16:05.449  BTCUSDT  69284.01
#                         E        s         c
# 0 2024-04-07 12:16:06.472  BTCUSDT  69284.01
#                         E        s         c
# 0 2024-04-07 12:16:07.316  BTCUSDT  69284.01
#                         E        s         c
# 0 2024-04-07 12:16:08.521  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:09.065  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:10.413  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:10.928  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:12.535  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:13.291  BTCUSDT  69284.02
#                         E        s         c
# 0 2024-04-07 12:16:13.888  BTCUSDT  69284.02
