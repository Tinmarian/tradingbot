# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp310-cp310-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 8.2 MB/s eta 0:00:00
# Collecting numpy>=1.22.4
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#      ---------------------------------------- 15.8/15.8 MB 7.7 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      -------------------------------------- 505.5/505.5 kB 7.9 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      -------------------------------------- 345.4/345.4 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.16.1-cp310-cp310-win_amd64.whl (2.1 kB)
# Collecting tensorflow-intel==2.16.1
#   Using cached tensorflow_intel-2.16.1-cp310-cp310-win_amd64.whl (376.9 MB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#      -------------------------------------- 413.4/413.4 kB 1.5 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting tensorboard<2.17,>=2.16
#   Using cached tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
# Collecting libclang>=13.0.0
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      --------------------------------------- 62.6/62.6 kB 62.1 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Collecting ml-dtypes~=0.3.1
#   Using cached ml_dtypes-0.3.2-cp310-cp310-win_amd64.whl (127 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.62.1-cp310-cp310-win_amd64.whl (3.8 MB)
#      ---------------------------------------- 3.8/3.8 MB 2.8 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.11.0)
# Collecting keras>=3.0.0
#   Using cached keras-3.2.1-py3-none-any.whl (1.1 MB)
# Collecting flatbuffers>=23.5.26
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: packaging in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: setuptools in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (63.2.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.16.0-cp310-cp310-win_amd64.whl (37 kB)
# Collecting h5py>=3.10.0
#   Using cached h5py-3.11.0-cp310-cp310-win_amd64.whl (3.0 MB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# Collecting namex
#   Using cached namex-0.0.7-py3-none-any.whl (5.8 kB)
# Collecting optree
#   Using cached optree-0.11.0-cp310-cp310-win_amd64.whl (243 kB)
# Collecting rich
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ------------------------------------- 240.7/240.7 kB 14.4 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ---------------------------------------- 121.1/121.1 kB ? eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ---------------------------------------- 66.8/66.8 kB ? eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ---------------------------------------- 163.8/163.8 kB ? eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
#      ---------------------------------------- 100.3/100.3 kB ? eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.0.2-py3-none-any.whl (226 kB)
#      ------------------------------------- 226.8/226.8 kB 13.5 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#      ---------------------------------------- 105.4/105.4 kB ? eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.17.2)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, optree, opt-einsum, ml-dtypes, mdurl, MarkupSafe, markdown, idna, h5py, grpcio, google-pasta, gast, charset-normalizer, certifi, absl-py, werkzeug, requests, markdown-it-py, astunparse, tensorboard, rich, keras, tensorflow-intel, tensorflow
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 certifi-2024.2.2 charset-normalizer-3.3.2 flatbuffers-24.3.25 gast-0.5.4 google-pasta-0.2.0 grpcio-1.62.1 h5py-3.11.0 idna-3.7 keras-3.2.1 libclang-18.1.1 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.0.7 opt-einsum-3.3.0 optree-0.11.0 protobuf-4.25.3 requests-2.31.0 rich-13.7.1 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-intel-2.16.1 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.4.0 urllib3-2.2.1 werkzeug-3.0.2 wheel-0.43.0 wrapt-1.16.0
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: wheel in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from -r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 1)) (0.43.0)
# Collecting nvidia-cuda-runtime-cu11
#   Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from -r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 3)) (1.26.4)
# Collecting scipy
#   Downloading scipy-1.13.0-cp310-cp310-win_amd64.whl (46.2 MB)
#      --------------------------------------- 46.2/46.2 MB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from -r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 5)) (2.2.2)
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp310-cp310-win_amd64.whl (7.7 MB)
#      ---------------------------------------- 7.7/7.7 MB 14.4 MB/s eta 0:00:00
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp310-cp310-win_amd64.whl (10.6 MB)
#      --------------------------------------- 10.6/10.6 MB 14.2 MB/s eta 0:00:00
# Collecting torch
#   Downloading torch-2.2.2-cp310-cp310-win_amd64.whl (198.6 MB)
#      -------------------------------------- 198.6/198.6 MB 8.8 MB/s eta 0:00:00
# Collecting torchvision
#   Downloading torchvision-0.17.2-cp310-cp310-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 14.8 MB/s eta 0:00:00
# Collecting torchaudio
#   Downloading torchaudio-2.2.2-cp310-cp310-win_amd64.whl (2.4 MB)
#      ---------------------------------------- 2.4/2.4 MB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from pandas->-r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from pandas->-r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from pandas->-r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 5)) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp310-cp310-win_amd64.whl (187 kB)
#      ------------------------------------- 187.5/187.5 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from matplotlib->-r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 6)) (24.0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-10.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 16.1 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.51.0-cp310-cp310-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 17.4 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      -------------------------------------- 103.2/103.2 kB 5.8 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#      ------------------------------------- 301.2/301.2 kB 18.2 MB/s eta 0:00:00
# Collecting fsspec
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ------------------------------------- 172.0/172.0 kB 10.8 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.2/133.2 kB 7.7 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.13.4-py3-none-any.whl (11 kB)
# Collecting networkx
#   Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 18.0 MB/s eta 0:00:00
# Collecting sympy
#   Downloading https://download.pytorch.org/whl/sympy-1.12-py3-none-any.whl (5.7 MB)
#      ---------------------------------------- 5.7/5.7 MB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from torch->-r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 9)) (4.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from jinja2->torch->-r C:/Users/tinma/OneDrive/Escritorio/GPU_Computing/install-and-test-gpu/pytorch_utils/pytorch_requirements.txt (line 9)) (2.1.5)
# Collecting mpmath>=0.19
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ------------------------------------- 536.2/536.2 kB 17.0 MB/s eta 0:00:00
# Installing collected packages: mpmath, threadpoolctl, sympy, scipy, pyparsing, pillow, nvidia-cuda-runtime-cu11, networkx, kiwisolver, joblib, jinja2, fsspec, fonttools, filelock, cycler, contourpy, torch, scikit-learn, matplotlib, torchvision, torchaudio
# Successfully installed contourpy-1.2.1 cycler-0.12.1 filelock-3.13.4 fonttools-4.51.0 fsspec-2024.3.1 jinja2-3.1.3 joblib-1.4.0 kiwisolver-1.4.5 matplotlib-3.8.4 mpmath-1.3.0 networkx-3.3 nvidia-cuda-runtime-cu11-11.8.89 pillow-10.3.0 pyparsing-3.1.2 scikit-learn-1.4.2 scipy-1.13.0 sympy-1.12 threadpoolctl-3.4.0 torch-2.2.2 torchaudio-2.2.2 torchvision-0.17.2
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install torch==1.12.0+cu113 torchvision==0.13.0+cu113 torchaudio===0.12.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Collecting torch==1.12.0+cu113
#   Using cached https://download.pytorch.org/whl/cu113/torch-1.12.0%2Bcu113-cp310-cp310-win_amd64.whl (2143.8 MB)
# Collecting torchvision==0.13.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.13.0%2Bcu113-cp310-cp310-win_amd64.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 6.3 MB/s eta 0:00:00
# Collecting torchaudio===0.12.0+cu113
#   Using cached https://download.pytorch.org/whl/cu113/torchaudio-0.12.0%2Bcu113-cp310-cp310-win_amd64.whl (1.2 MB)
# Requirement already satisfied: typing-extensions in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from torch==1.12.0+cu113) (4.11.0)
# Requirement already satisfied: numpy in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from torchvision==0.13.0+cu113) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from torchvision==0.13.0+cu113) (10.3.0)
# Requirement already satisfied: requests in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from torchvision==0.13.0+cu113) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from requests->torchvision==0.13.0+cu113) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from requests->torchvision==0.13.0+cu113) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from requests->torchvision==0.13.0+cu113) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tinma\onedrive\escritorio\tradingbot\gpu_tradingbot\lib\site-packages (from requests->torchvision==0.13.0+cu113) (2024.2.2)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.2
#     Uninstalling torch-2.2.2:
#       Successfully uninstalled torch-2.2.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\tinma\\OneDrive\\Escritorio\\tradingbot\\gpu_tradingbot\\Lib\\site-packages\\~orch\\lib\\asmjit.dll'
# Check the permissions.
#
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import torch

class BasicClassif(torch.nn.Module):
    def __init__(self):
        super(BasicClassif, self).__init__()
        self.fc1 = torch.nn.Linear(28*28, 128)
        self.fc2 = torch.nn.Linear(128, 10)
        self.dp = torch.nn.Dropout(0.2)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = torch.relu(x)
        x = self.dp(x)
        x = self.fc2(x)
        return x

# %%
import torch

def torch_info():
    print('Torch version:', torch.__version__)
    print('Torch is build with CUDA:', torch.cuda.is_available())

def gpu_info():
    gpu_number = torch.cuda.device_count()
    print('GPU is available:', gpu_number > 0)
    if gpu_number > 0:
        print('Torch GPU count:', gpu_number)
        for ind in range(gpu_number):
            print("*"*20)
            print("GPU {}:".format(ind))
            print("Device name:", torch.cuda.get_device_name(ind))
            print("Compute capability:", torch.cuda.get_device_capability(ind))
            print("Memory:", torch.cuda.get_device_properties(ind).total_memory/1024/1024, "MB")

# %%
import torch
import torchvision


def get_dataloaders(download=True, batch_size=64, num_workers=0, pin_memory=False):
    transform = torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.1307,), (0.3081,))
        ])

    train_dataset = torchvision.datasets.MNIST('./data', train=True, download=download,
                       transform=transform)
    test_dataset = torchvision.datasets.MNIST('./data', train=False,
                       transform=transform)

    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                               shuffle=True, num_workers=num_workers,
                                               pin_memory=pin_memory)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,
                                              shuffle=False, num_workers=num_workers,
                                              pin_memory=pin_memory)
    return train_loader, test_loader


def train(model, device, train_loader, optimizer, loss_fn, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 400 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))


def test(model, device, test_loader, loss_fn):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += torch.sum(loss_fn(output, target)).item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
import torch
import torchvision

# from pytorch_utils import architecture, get_info, training

if __name__=="__main__":


    torch_info()
    gpu_info()

    print()

    train_loader, test_loader = get_dataloaders(download=True,
                                                    batch_size=64,
                                                    num_workers=0,
                                                    pin_memory=False)

    model = BasicClassif().to("cuda")
    loss = torch.nn.CrossEntropyLoss().to("cuda")
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    for epoch in range(1, 6):
        train(model, torch.device('cuda'), train_loader, optimizer, loss, epoch)
        test(model, torch.device('cuda'), test_loader, loss)
# Out:
# Torch version: 1.12.0+cu113
# Torch is build with CUDA: True
# GPU is available: True
# Torch GPU count: 1
# ********************
# GPU 0:
# Device name: NVIDIA GeForce RTX 3060 Laptop GPU
# Compute capability: (8, 6)
# Memory: 6143.5 MB
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.349997
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.238603
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.035222
#
# Test set: Average loss: 0.0023, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.109069
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.110170
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.087887
#
# Test set: Average loss: 0.0015, Accuracy: 9708/10000 (97%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.136512
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.085168
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.086899
#
# Test set: Average loss: 0.0015, Accuracy: 9708/10000 (97%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.071871
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.072770
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.050469
#
# Test set: Average loss: 0.0012, Accuracy: 9753/10000 (98%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.018699
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.036774
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.073414
#
# Test set: Average loss: 0.0012, Accuracy: 9755/10000 (98%)
