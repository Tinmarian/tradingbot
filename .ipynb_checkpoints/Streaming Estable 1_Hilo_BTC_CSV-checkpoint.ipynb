# %%
# !pip install unicorn-binance-websocket-api
# Out:
# Collecting unicorn-binance-websocket-api
#   Obtaining dependency information for unicorn-binance-websocket-api from https://files.pythonhosted.org/packages/1a/77/5a95495007c9fcc10e1458a10f761570624267d30a3bd67e0af0e435d63f/unicorn_binance_websocket_api-2.4.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading unicorn_binance_websocket_api-2.4.0-cp310-cp310-win_amd64.whl.metadata (49 kB)
#      -------------------------------------- 49.6/49.6 kB 837.9 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\tinma\appdata\roaming\python\python310\site-packages (from unicorn-binance-websocket-api) (0.4.5)
# Requirement already satisfied: requests in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api) (2.28.2)
# Requirement already satisfied: websocket-client in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api) (1.6.1)
# Requirement already satisfied: websockets==11.0.3 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api) (11.0.3)
# Collecting flask-restful (from unicorn-binance-websocket-api)
#   Obtaining dependency information for flask-restful from https://files.pythonhosted.org/packages/d7/7b/f0b45f0df7d2978e5ae51804bb5939b7897b2ace24306009da0cc34d8d1f/Flask_RESTful-0.3.10-py2.py3-none-any.whl.metadata
#   Downloading Flask_RESTful-0.3.10-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting cheroot (from unicorn-binance-websocket-api)
#   Obtaining dependency information for cheroot from https://files.pythonhosted.org/packages/81/52/ca26d1964531e823961f761026138189f630aaf49fb959c8ab6e1262dc74/cheroot-10.0.0-py3-none-any.whl.metadata
#   Downloading cheroot-10.0.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: flask in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api) (2.2.2)
# Collecting lucit-licensing-python (from unicorn-binance-websocket-api)
#   Obtaining dependency information for lucit-licensing-python from https://files.pythonhosted.org/packages/f6/16/b13727d47e8cf4e689125c2f3464bb2662a6b959a7bad93567fddcd61ec5/lucit_licensing_python-1.8.2-cp310-cp310-win_amd64.whl.metadata
#   Downloading lucit_licensing_python-1.8.2-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: ujson in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api) (5.8.0)
# Requirement already satisfied: psutil in c:\users\tinma\appdata\roaming\python\python310\site-packages (from unicorn-binance-websocket-api) (5.9.2)
# Collecting PySocks (from unicorn-binance-websocket-api)
#   Obtaining dependency information for PySocks from https://files.pythonhosted.org/packages/8d/59/b4572118e098ac8e46e399a1dd0f2d85403ce8bbaad9ec79373ed6badaf9/PySocks-1.7.1-py3-none-any.whl.metadata
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting unicorn-fy (from unicorn-binance-websocket-api)
#   Obtaining dependency information for unicorn-fy from https://files.pythonhosted.org/packages/7f/ce/1adeb04abd91ceeba2b4b4959c62ceebcac79cbdf8f2c2f924928f84790e/unicorn_fy-1.14.1-cp310-cp310-win_amd64.whl.metadata
#   Downloading unicorn_fy-1.14.1-cp310-cp310-win_amd64.whl.metadata (23 kB)
# Collecting unicorn-binance-rest-api (from unicorn-binance-websocket-api)
#   Obtaining dependency information for unicorn-binance-rest-api from https://files.pythonhosted.org/packages/22/72/41b451dd44c38fb73e90ce514d6636a92c5f0215bece7bccd460a76f523e/unicorn_binance_rest_api-2.2.1-cp310-cp310-win_amd64.whl.metadata
#   Downloading unicorn_binance_rest_api-2.2.1-cp310-cp310-win_amd64.whl.metadata (27 kB)
# Requirement already satisfied: typing-extensions in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api) (4.7.1)
# Collecting Cython (from unicorn-binance-websocket-api)
#   Obtaining dependency information for Cython from https://files.pythonhosted.org/packages/83/42/9537a513d7d83196ab5973d911056eb22a639e04162fd649cf74b4dac3f1/Cython-3.0.10-cp310-cp310-win_amd64.whl.metadata
#   Downloading Cython-3.0.10-cp310-cp310-win_amd64.whl.metadata (3.2 kB)
# Collecting more-itertools>=2.6 (from cheroot->unicorn-binance-websocket-api)
#   Obtaining dependency information for more-itertools>=2.6 from https://files.pythonhosted.org/packages/50/e2/8e10e465ee3987bb7c9ab69efb91d867d93959095f4807db102d07995d94/more_itertools-10.2.0-py3-none-any.whl.metadata
#   Downloading more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting jaraco.functools (from cheroot->unicorn-binance-websocket-api)
#   Obtaining dependency information for jaraco.functools from https://files.pythonhosted.org/packages/4c/57/726a9c80c1b36f98b497debd72f4c81ae444d55abf9647367e5d53e1cc93/jaraco.functools-4.0.0-py3-none-any.whl.metadata
#   Downloading jaraco.functools-4.0.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask->unicorn-binance-websocket-api) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask->unicorn-binance-websocket-api) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask->unicorn-binance-websocket-api) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask->unicorn-binance-websocket-api) (8.1.3)
# Collecting aniso8601>=0.82 (from flask-restful->unicorn-binance-websocket-api)
#   Obtaining dependency information for aniso8601>=0.82 from https://files.pythonhosted.org/packages/e3/04/e97c12dc034791d7b504860acfcdd2963fa21ae61eaca1c9d31245f812c3/aniso8601-9.0.1-py2.py3-none-any.whl.metadata
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: six>=1.3.0 in c:\users\tinma\appdata\roaming\python\python310\site-packages (from flask-restful->unicorn-binance-websocket-api) (1.16.0)
# Requirement already satisfied: pytz in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask-restful->unicorn-binance-websocket-api) (2022.6)
# Collecting simplejson (from lucit-licensing-python->unicorn-binance-websocket-api)
#   Obtaining dependency information for simplejson from https://files.pythonhosted.org/packages/7f/60/b0071b60e9318bb5c3716e5c0d506d61350670b7fba9a8532ebf3959b88a/simplejson-3.19.2-cp310-cp310-win_amd64.whl.metadata
#   Downloading simplejson-3.19.2-cp310-cp310-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests->unicorn-binance-websocket-api) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests->unicorn-binance-websocket-api) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests->unicorn-binance-websocket-api) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests->unicorn-binance-websocket-api) (2022.12.7)
# Requirement already satisfied: cryptography in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api->unicorn-binance-websocket-api) (39.0.1)
# Requirement already satisfied: dateparser in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api->unicorn-binance-websocket-api) (1.1.8)
# Collecting pyOpenSSL (from unicorn-binance-rest-api->unicorn-binance-websocket-api)
#   Obtaining dependency information for pyOpenSSL from https://files.pythonhosted.org/packages/54/a7/2104f674a5a6845b04c8ff01659becc6b8978ca410b82b94287e0b1e018b/pyOpenSSL-24.1.0-py3-none-any.whl.metadata
#   Downloading pyOpenSSL-24.1.0-py3-none-any.whl.metadata (12 kB)
# Collecting service-identity (from unicorn-binance-rest-api->unicorn-binance-websocket-api)
#   Obtaining dependency information for service-identity from https://files.pythonhosted.org/packages/3b/92/44669afe6354a7bed9968013862118c401690d8b5a805bab75ac1764845f/service_identity-24.1.0-py3-none-any.whl.metadata
#   Downloading service_identity-24.1.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: regex in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api->unicorn-binance-websocket-api) (2023.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.0->flask->unicorn-binance-websocket-api) (2.1.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from cryptography->unicorn-binance-rest-api->unicorn-binance-websocket-api) (1.15.1)
# Requirement already satisfied: python-dateutil in c:\users\tinma\appdata\roaming\python\python310\site-packages (from dateparser->unicorn-binance-rest-api->unicorn-binance-websocket-api) (2.8.2)
# Requirement already satisfied: tzlocal in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from dateparser->unicorn-binance-rest-api->unicorn-binance-websocket-api) (5.0.1)
# Collecting cryptography (from unicorn-binance-rest-api->unicorn-binance-websocket-api)
#   Obtaining dependency information for cryptography from https://files.pythonhosted.org/packages/e3/14/13acd84f2a8303d9410ba2e24534a9d90c2817583636a91c4f314224768d/cryptography-42.0.5-cp39-abi3-win_amd64.whl.metadata
#   Downloading cryptography-42.0.5-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from service-identity->unicorn-binance-rest-api->unicorn-binance-websocket-api) (22.2.0)
# Requirement already satisfied: pyasn1 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from service-identity->unicorn-binance-rest-api->unicorn-binance-websocket-api) (0.5.0)
# Requirement already satisfied: pyasn1-modules in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from service-identity->unicorn-binance-rest-api->unicorn-binance-websocket-api) (0.3.0)
# Requirement already satisfied: pycparser in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography->unicorn-binance-rest-api->unicorn-binance-websocket-api) (2.21)
# Requirement already satisfied: tzdata in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from tzlocal->dateparser->unicorn-binance-rest-api->unicorn-binance-websocket-api) (2023.3)
# Downloading unicorn_binance_websocket_api-2.4.0-cp310-cp310-win_amd64.whl (954 kB)
#    ---------------------------------------- 954.3/954.3 kB 6.1 MB/s eta 0:00:00
# Downloading cheroot-10.0.0-py3-none-any.whl (101 kB)
#    ---------------------------------------- 101.6/101.6 kB ? eta 0:00:00
# Downloading Cython-3.0.10-cp310-cp310-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 2.8/2.8 MB 16.2 MB/s eta 0:00:00
# Downloading Flask_RESTful-0.3.10-py2.py3-none-any.whl (26 kB)
# Downloading lucit_licensing_python-1.8.2-cp310-cp310-win_amd64.whl (164 kB)
#    ---------------------------------------- 165.0/165.0 kB 9.7 MB/s eta 0:00:00
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading unicorn_binance_rest_api-2.2.1-cp310-cp310-win_amd64.whl (343 kB)
#    --------------------------------------- 343.3/343.3 kB 22.2 MB/s eta 0:00:00
# Downloading unicorn_fy-1.14.1-cp310-cp310-win_amd64.whl (142 kB)
#    ---------------------------------------- 142.6/142.6 kB 8.3 MB/s eta 0:00:00
# Using cached aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
# Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 57.0/57.0 kB ? eta 0:00:00
# Downloading jaraco.functools-4.0.0-py3-none-any.whl (9.8 kB)
# Downloading pyOpenSSL-24.1.0-py3-none-any.whl (56 kB)
#    ---------------------------------------- 56.9/56.9 kB ? eta 0:00:00
# Downloading cryptography-42.0.5-cp39-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 2.9/2.9 MB 18.5 MB/s eta 0:00:00
# Downloading service_identity-24.1.0-py3-none-any.whl (12 kB)
# Downloading simplejson-3.19.2-cp310-cp310-win_amd64.whl (75 kB)
#    ---------------------------------------- 75.5/75.5 kB ? eta 0:00:00
# Installing collected packages: aniso8601, simplejson, PySocks, more-itertools, Cython, unicorn-fy, lucit-licensing-python, jaraco.functools, cryptography, service-identity, pyOpenSSL, flask-restful, cheroot, unicorn-binance-rest-api, unicorn-binance-websocket-api
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 39.0.1
#     Uninstalling cryptography-39.0.1:
#       Successfully uninstalled cryptography-39.0.1
# Successfully installed Cython-3.0.10 PySocks-1.7.1 aniso8601-9.0.1 cheroot-10.0.0 cryptography-42.0.5 flask-restful-0.3.10 jaraco.functools-4.0.0 lucit-licensing-python-1.8.2 more-itertools-10.2.0 pyOpenSSL-24.1.0 service-identity-24.1.0 simplejson-3.19.2 unicorn-binance-rest-api-2.2.1 unicorn-binance-websocket-api-2.4.0 unicorn-fy-1.14.1
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install unicorn-binance-suite
# Out:
# Collecting unicorn-binance-suite
#   Downloading unicorn_binance_suite-2.0.0.tar.gz (14 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: unicorn-binance-websocket-api>=2.0.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-suite) (2.4.0)
# Requirement already satisfied: unicorn-binance-rest-api>=2.0.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-suite) (2.2.1)
# Requirement already satisfied: unicorn-fy>=0.13.1 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-suite) (1.14.1)
# Collecting unicorn-binance-local-depth-cache>=1.0.0 (from unicorn-binance-suite)
#   Obtaining dependency information for unicorn-binance-local-depth-cache>=1.0.0 from https://files.pythonhosted.org/packages/b6/7b/17d4091b6ae549de24093b78a43f1cbf3bb56c9a96a6d9b3351aaba18ffc/unicorn_binance_local_depth_cache-1.0.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading unicorn_binance_local_depth_cache-1.0.0-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Collecting unicorn-binance-trailing-stop-loss>=1.0.0 (from unicorn-binance-suite)
#   Obtaining dependency information for unicorn-binance-trailing-stop-loss>=1.0.0 from https://files.pythonhosted.org/packages/27/aa/0b4c477c3c73bba5b3cb68aece947d0ad1d219d5717df009b43b8fe6081f/unicorn_binance_trailing_stop_loss-1.1.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading unicorn_binance_trailing_stop_loss-1.1.0-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: lucit-licensing-python>=1.8.1 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-suite) (1.8.2)
# Requirement already satisfied: Cython in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from lucit-licensing-python>=1.8.1->unicorn-binance-suite) (3.0.10)
# Requirement already satisfied: requests in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from lucit-licensing-python>=1.8.1->unicorn-binance-suite) (2.28.2)
# Requirement already satisfied: simplejson in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from lucit-licensing-python>=1.8.1->unicorn-binance-suite) (3.19.2)
# Requirement already satisfied: certifi in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\tinma\appdata\roaming\python\python310\site-packages (from unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (0.4.5)
# Requirement already satisfied: cryptography in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (42.0.5)
# Requirement already satisfied: dateparser in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (1.1.8)
# Requirement already satisfied: pyOpenSSL in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (24.1.0)
# Requirement already satisfied: service-identity in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (24.1.0)
# Requirement already satisfied: ujson in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (5.8.0)
# Requirement already satisfied: regex in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (2023.6.3)
# Requirement already satisfied: PySocks in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (1.7.1)
# Requirement already satisfied: websocket-client in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (1.6.1)
# Requirement already satisfied: websockets==11.0.3 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (11.0.3)
# Requirement already satisfied: flask-restful in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (0.3.10)
# Requirement already satisfied: cheroot in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (10.0.0)
# Requirement already satisfied: flask in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (2.2.2)
# Requirement already satisfied: psutil in c:\users\tinma\appdata\roaming\python\python310\site-packages (from unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (5.9.2)
# Requirement already satisfied: typing-extensions in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (4.7.1)
# Requirement already satisfied: more-itertools>=2.6 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from cheroot->unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (10.2.0)
# Requirement already satisfied: jaraco.functools in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from cheroot->unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (4.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from cryptography->unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (1.15.1)
# Requirement already satisfied: python-dateutil in c:\users\tinma\appdata\roaming\python\python310\site-packages (from dateparser->unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (2.8.2)
# Requirement already satisfied: pytz in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from dateparser->unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (2022.6)
# Requirement already satisfied: tzlocal in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from dateparser->unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (5.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask->unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask->unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask->unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask->unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (8.1.3)
# Requirement already satisfied: aniso8601>=0.82 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from flask-restful->unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (9.0.1)
# Requirement already satisfied: six>=1.3.0 in c:\users\tinma\appdata\roaming\python\python310\site-packages (from flask-restful->unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests->lucit-licensing-python>=1.8.1->unicorn-binance-suite) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests->lucit-licensing-python>=1.8.1->unicorn-binance-suite) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests->lucit-licensing-python>=1.8.1->unicorn-binance-suite) (1.26.14)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from service-identity->unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (22.2.0)
# Requirement already satisfied: pyasn1 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from service-identity->unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (0.5.0)
# Requirement already satisfied: pyasn1-modules in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from service-identity->unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (0.3.0)
# Requirement already satisfied: pycparser in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography->unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.0->flask->unicorn-binance-websocket-api>=2.0.0->unicorn-binance-suite) (2.1.2)
# Requirement already satisfied: tzdata in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from tzlocal->dateparser->unicorn-binance-rest-api>=2.0.0->unicorn-binance-suite) (2023.3)
# Downloading unicorn_binance_local_depth_cache-1.0.0-cp310-cp310-win_amd64.whl (154 kB)
#    ---------------------------------------- 154.8/154.8 kB 1.9 MB/s eta 0:00:00
# Downloading unicorn_binance_trailing_stop_loss-1.1.0-cp310-cp310-win_amd64.whl (253 kB)
#    ---------------------------------------- 254.0/254.0 kB 5.2 MB/s eta 0:00:00
# Building wheels for collected packages: unicorn-binance-suite
#   Building wheel for unicorn-binance-suite (pyproject.toml): started
#   Building wheel for unicorn-binance-suite (pyproject.toml): finished with status 'done'
#   Created wheel for unicorn-binance-suite: filename=unicorn_binance_suite-2.0.0-py3-none-any.whl size=9131 sha256=d505658b5eaf1297f0ebe3d475d8f2f886260e70bb0f63d77365b2101d7a6d39
#   Stored in directory: c:\users\tinma\appdata\local\pip\cache\wheels\e7\d9\bb\d042781ab75e0b7edd938b9b87e9d18f224d692ed76dd3ac98
# Successfully built unicorn-binance-suite
# Installing collected packages: unicorn-binance-trailing-stop-loss, unicorn-binance-local-depth-cache, unicorn-binance-suite
# Successfully installed unicorn-binance-local-depth-cache-1.0.0 unicorn-binance-suite-2.0.0 unicorn-binance-trailing-stop-loss-1.1.0
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from unicorn_binance_websocket_api import BinanceWebSocketApiManager
from IPython.display import clear_output
import pandas as pd
import time
from datetime import date
from datetime import datetime


bws = BinanceWebSocketApiManager(exchange="binance.com")
bws.create_stream(['trade'], ['btcusdt'], output = "UnicornFy")

i = 0
df = pd.DataFrame()

while True:
    oldest_data_from_stream_buffer = bws.pop_stream_data_from_stream_buffer()
    if oldest_data_from_stream_buffer:
        df = pd.DataFrame([oldest_data_from_stream_buffer])
        if df.columns[0] == 'result':
            print(df.columns)
        else:
            df['Tiempo_evento'] = pd.to_datetime(df.event_time, unit='ms').item().strftime('%H:%M:%S.%f')
            df['Tiempo_trade'] = pd.to_datetime(df.trade_time, unit='ms').item().strftime('%H:%M:%S.%f')
            df = df.assign(Tiempo_actual=datetime.utcnow())
            df.Tiempo_actual = df.Tiempo_actual.item().strftime('%H:%M:%S.%f')
            df = df.assign(Año_actual = pd.to_datetime(df.Tiempo_actual).item().strftime('%y'))
            df = df.assign(Año_trade = pd.to_datetime(df.trade_time, unit='ms').item().strftime('%y'))
            df = df.assign(Mes_actual = pd.to_datetime(df.Tiempo_actual).item().strftime('%m'))
            df = df.assign(Mes_trade = pd.to_datetime(df.trade_time, unit='ms').item().strftime('%m'))
            df = df.assign(Dia_actual = pd.to_datetime(df.Tiempo_actual).item().strftime('%d'))
            df = df.assign(Dia_trade = pd.to_datetime(df.trade_time, unit='ms').item().strftime('%d'))
            df = df.assign(Hora_actual = pd.to_datetime(df.Tiempo_actual).item().strftime('%H'))
            df = df.assign(Hora_trade = pd.to_datetime(df.trade_time, unit='ms').item().strftime('%H'))
            df = df.assign(Minuto_Actual = pd.to_datetime(df.Tiempo_actual).item().strftime('%M'))
            df = df.assign(Minuto_trade = pd.to_datetime(df.trade_time, unit='ms').item().strftime('%M'))
            df = df.assign(Segundo_Actual = pd.to_datetime(df.Tiempo_actual).item().strftime('%S'))
            df = df.assign(Segundo_trade = pd.to_datetime(df.trade_time, unit='ms').item().strftime('%S'))
            df = df.assign(Milisegundo_Actual = pd.to_datetime(df.Tiempo_actual).item().strftime('%f'))
            df = df.assign(Milisegundo_trade = pd.to_datetime(df.trade_time, unit='ms').item().strftime('%f'))
            df = df.loc[:,[
                            'Año_actual', 'Año_trade', 'Mes_actual', 'Mes_trade', 'Dia_actual', 'Dia_trade',  'Hora_actual', 'Hora_trade', 
                            'Minuto_Actual', 'Minuto_trade', 'Segundo_Actual', 'Segundo_trade', 'Milisegundo_Actual', 'Milisegundo_trade', 
                            'Tiempo_evento', 'Tiempo_trade', 'Tiempo_actual', 'buyer_order_id', 'seller_order_id', 'trade_id',
                            'symbol', 'price', 'quantity', 'is_market_maker']]
            df.columns = [
                            'Anio_actual', 'Anio_trade', 'Mes_actual', 'Mes_trade', 'Dia_actual', 'Dia_trade',  'Hora_actual', 
                            'Hora_trade', 'Minuto_Actual', 'Minuto_trade', 'Segundo_Actual', 'Segundo_trade','Milisegundo_Actual', 
                            'Milisegundo_trade', "Tiempo_Evento", "Tiempo_Trade", "Tiempo_Actual", "ID_pedido_comprador", 
                            "ID_pedido_vendedor", "ID_trade", "Simbolo", "Precio", "Cantidad", "Vendedor"
                            ]
            df = df.assign(Total_USD = float(df.Precio)*float(df.Cantidad))
            if i == 0:
                df.to_csv(                                    
                    path_or_buf = r'D:\BTCUSDT_1coin_prueba_00.csv',
                    index=False,
                    sep=',',
                    encoding='utf-8',
                    mode='a',
                    header=True
                    )
            else:
                df.to_csv(                                    
                    path_or_buf = r'D:\BTCUSDT_1coin_prueba_00.csv',
                    index=False,
                    sep=',',
                    encoding='utf-8',
                    mode='a',
                    header=False
                    )
            i = i + 1
            print(df)
            clear_output(wait=True)
# Out:
# Please provide the api secret and license token of your lucit license! Read this article for more information: https://medium.lucit.tech/87b0088124a8
# LUCIT License Manager is shutting down!
# ---------------------------------------------------------------------------
# NoValidatedLucitLicense                   Traceback (most recent call last)
# Cell In [6], line 9
#       5 from datetime import date
#       6 from datetime import datetime
# ----> 9 bws = BinanceWebSocketApiManager(exchange="binance.com")
#      10 bws.create_stream(['trade'], ['btcusdt'], output = "UnicornFy")
#      12 i = 0
#
# File unicorn_binance_websocket_api\\manager.py:272, in unicorn_binance_websocket_api.manager.BinanceWebSocketApiManager.__init__()
#
# File unicorn_binance_websocket_api\\licensing_manager.py:136, in unicorn_binance_websocket_api.licensing_manager.LucitLicensingManager.__init__()
#
# NoValidatedLucitLicense: Please provide the api secret and license token of your lucit license! Read this article for more information: https://medium.lucit.tech/87b0088124a8
