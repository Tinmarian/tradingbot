# %%
# !pip install scipy

# %%
from binance import Client
from datetime import datetime, timedelta
client = Client(api_key="jM9zEeTTzT7R7QGlNrh5tUpOc8l71hOxu7CewCL4M0NvbBp3ilgmEwMOOjJfCRVB",api_secret="iZxFmlz5bvROsHQPZTP5hlJtsxYjOu8wocOlLWzIDdhMzEQu7KyyHB2DseOYQ66s",testnet=True)

import os
from google.cloud.sql.connector import Connector
from sqlalchemy import create_engine, text
import pg8000.native
import pandas as pd

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'C:/Users/tinma/OneDrive/Escritorio/application_default_credentials.json'

connector = Connector()

def getconn() -> pg8000.native.Connection:
    conn: pg8000.native.Connection = connector.connect(
        "semiotic-pact-388619:us-central1:tradingbot",
        "pg8000",
        user="postgres",
        password="GuruSat.3",
        db="criptos"
    )
    return conn

connection = create_engine('postgresql+pg8000://',creator=getconn)

def MACD(df):
    df['EMA12'] = df.Precio.ewm(span=12).mean()
    df['EMA26'] = df.Precio.ewm(span=26).mean()
    df['MACD'] = df.EMA12 - df.EMA26
    df['Signal'] = df.MACD.ewm(span=9).mean()
    # print('Indicadores agregados')

def señal_MACD(df):
    buy, sell = [],[]
    for i in range(7,len(df)):
        if df.MACD.iloc[i] > df.Signal.iloc[i] and df.MACD.iloc[i-1] < df.Signal.iloc[i-1]:
            buy.append(i)
        elif df.MACD.iloc[i] < df.Signal.iloc[i] and df.MACD.iloc[i-1] > df.Signal.iloc[i-1]:
            sell.append(i)
    return buy, sell

# %%
info = client.get_isolated_margin_symbol(symbol='BTCUSDT')
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# c:\Users\tinma\OneDrive\Escritorio\tradingbot\estrategias_scripts\testnet\MACD_prueba.ipynb Celda 3 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tinma/OneDrive/Escritorio/tradingbot/estrategias_scripts/testnet/MACD_prueba.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> info = client.get_isolated_margin_symbol(symbol='BTCUSDT')
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:3307, in Client.get_isolated_margin_symbol(self, **params)
#    3278 def get_isolated_margin_symbol(self, **params):
#    3279     """Query isolated margin symbol info
#    3280
#    3281     https://binance-docs.github.io/apidocs/spot/en/#query-isolated-margin-symbol-user_data
#    (...)
#    3305
#    3306     """
# -> 3307     return self._request_margin_api('get', 'margin/isolated/pair', signed=True, data=params)
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:407, in Client._request_margin_api(self, method, path, signed, version, **kwargs)
#     404 def _request_margin_api(self, method, path, signed=False, version=1, **kwargs) -> Dict:
#     405     uri = self._create_margin_api_uri(path, version)
# --> 407     return self._request(method, uri, signed, **kwargs)
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:358, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     355 kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
#     357 self.response = getattr(self.session, method)(uri, **kwargs)
# --> 358 return self._handle_response(self.response)
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:367, in Client._handle_response(response)
#     362 """Internal helper for handling API responses from the Binance server.
#     363 Raises the appropriate exceptions when necessary; otherwise, returns the
#     364 response.
#     365 """
#     366 if not (200 <= response.status_code < 300):
# --> 367     raise BinanceAPIException(response, response.status_code, response.text)
#     368 try:
#     369     return response.json()
#
# BinanceAPIException: APIError(code=-2008): Invalid Api-Key ID.

# %%
client.get_account()
# Out:
# {'makerCommission': 0,
#  'takerCommission': 0,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00000000',
#   'taker': '0.00000000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': False,
#  'canDeposit': False,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'updateTime': 1688459952317,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BNB',
#    'free': '1000.00000000',
#    'locked': '0.00000000'},
#   {'asset': 'BTC', 'free': '1.01000000', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '10000.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '100.20000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '500.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '500000.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '9255.73043351', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '50000.00000000', 'locked': '0.00000000'}],
#  'permissions': ['SPOT']}

# %%
day = datetime.utcnow() - timedelta(1)

with connection.connect() as conn:
    df =conn.execute(text(""" SELECT * FROM "BNBUSDT" WHERE "Tiempo" > '{day}' """.format(day=day))).mappings().all()
df = pd.DataFrame(df)[['Tiempo', 'Precio']].set_index('Tiempo')
df = df.sort_values(by='Tiempo')
df
# Out:
#                          Precio
# Tiempo
# 2023-06-29 15:29:03.006   233.8
# 2023-06-29 15:29:03.609   233.7
# 2023-06-29 15:29:04.923   233.8
# 2023-06-29 15:29:05.449   233.8
# 2023-06-29 15:29:09.831   233.8
# ...                         ...
# 2023-06-30 15:28:50.866   235.3
# 2023-06-30 15:28:51.597   235.3
# 2023-06-30 15:28:53.199   235.3
# 2023-06-30 15:28:53.677   235.3
# 2023-06-30 15:28:54.758   235.3
#
# [37722 rows x 1 columns]

# %%
day = datetime.utcnow() - timedelta(seconds=1000)

with connection.connect() as conn:
    df =conn.execute(text(""" SELECT * FROM "ETHUSDT" WHERE "Tiempo" > '{day}' """.format(day=day))).mappings().all()
df = pd.DataFrame(df)[['Tiempo', 'Precio']].set_index('Tiempo')
df = df.sort_values(by='Tiempo')
df
# Out:
#                           Precio
# Tiempo
# 2023-07-02 01:55:28.913  1919.00
# 2023-07-02 01:55:30.382  1919.01
# 2023-07-02 01:55:34.404  1918.78
# 2023-07-02 01:55:34.662  1918.65
# 2023-07-02 01:55:36.400  1918.62
# ...                          ...
# 2023-07-02 02:11:56.513  1919.38
# 2023-07-02 02:12:01.134  1919.38
# 2023-07-02 02:12:02.508  1919.38
# 2023-07-02 02:12:03.094  1919.38
# 2023-07-02 02:12:03.927  1919.38
#
# [317 rows x 1 columns]

# %%
def slopee(x1,y1,x2,y2):
    x = (y2 - y1) / (x2 - x1).total_seconds()
    return x
# Out:
# C:\Users\tinma\AppData\Local\Temp\ipykernel_33172\908954939.py:4: RuntimeWarning: invalid value encountered in double_scalars
#
        pendientes.append(x)

    df['pendiente'] = pendientes

    df['SMA3'] = pd.Series()
    df['SMA5'] = pd.Series()
    df['SMA7'] = pd.Series()
    df['SMA11'] = pd.Series()

    for i in range(2,len(df)-1):
        df['SMA3'][i] = df.pendiente[i-2:i+1].mean()
        if i < 14:
            df['SMA3'][i-3] = 0
    for i in range(4,len(df)-1):
        df['SMA5'][i] = df.pendiente[i-4:i+1].mean()
        if i < 16:
            df['SMA5'][i-5] = 0
    for i in range(6,len(df)-1):
        df['SMA7'][i] = df.pendiente[i-6:i+1].mean()
        if i < 18:
            df['SMA7'][i-7] = 0
    for i in range(10,len(df)-1):
        df['SMA11'][i] = df.pendiente[i-10:i+1].mean()
        if i < 22:
            df['SMA11'][i-11] = 0

# %%
df[0:50]
# Out:
#                            Precio  pendiente      SMA3      SMA5      SMA7  \
# Tiempo
# 2023-06-29 19:16:01.462  30512.00   0.000000  0.000000  0.000000  0.000000
# 2023-06-29 19:16:03.201  30512.00   0.000000  0.000000  0.000000  0.000000
# 2023-06-29 19:16:06.117  30512.00   0.000000  0.000000  0.000000  0.000000
# 2023-06-29 19:16:07.199  30511.99  -0.009242  0.000000  0.000000  0.000000
# 2023-06-29 19:16:10.954  30504.77  -1.922770  0.000000  0.000000  0.000000
# 2023-06-29 19:16:12.224  30504.77   0.000000  0.000000  0.000000  0.000000
# 2023-06-29 19:16:14.972  30504.77   0.000000  0.000000  0.000000  0.000000
# 2023-06-29 19:16:15.808  30504.78   0.011962  0.000000  0.000000  0.000000
# 2023-06-29 19:16:19.182  30504.77  -0.002964  0.000000  0.000000  0.000000
# 2023-06-29 19:16:20.237  30504.77   0.000000  0.000000  0.000000  0.000000
# 2023-06-29 19:16:24.687  30504.77   0.000000  0.000000  0.000000  0.000000
# 2023-06-29 19:16:28.232  30504.78   0.002821  0.000940  0.002364  0.001688
# 2023-06-29 19:16:28.963  30504.77  -0.013680 -0.003620 -0.002765 -0.000266
# 2023-06-29 19:16:33.998  30504.78   0.001986 -0.002958 -0.001775  0.000018
# 2023-06-29 19:16:37.168  30504.77  -0.003155 -0.004949 -0.002405 -0.002142
# 2023-06-29 19:16:38.251  30504.78   0.009234  0.002688 -0.000559 -0.000399
# 2023-06-29 19:16:41.039  30504.77  -0.003587  0.000831 -0.001840 -0.000912
# 2023-06-29 19:16:41.801  30504.77   0.000000  0.001882  0.000896 -0.000912
# 2023-06-29 19:16:46.346  30497.35  -1.632563 -0.545383 -0.326014 -0.234538
# 2023-06-29 19:16:47.294  30497.69   0.358650 -0.424638 -0.253653 -0.181348
# 2023-06-29 19:16:49.789  30497.70   0.004008 -0.423302 -0.254698 -0.181059
# 2023-06-29 19:16:51.359  30497.77   0.044586  0.135748 -0.245064 -0.174239
# 2023-06-29 19:16:54.054  30498.18   0.152134  0.066909 -0.214637 -0.153825
# 2023-06-29 19:16:55.350  30499.22   0.802469  0.333063  0.272369 -0.038674
# 2023-06-29 19:16:59.398  30503.09   0.956028  0.636877  0.391845  0.097902
# 2023-06-29 19:17:00.048  30503.75   1.015385  0.924627  0.594120  0.476180
# 2023-06-29 19:17:02.651  30505.54   0.687668  0.886360  0.722737  0.523182
# 2023-06-29 19:17:03.636  30505.90   0.365482  0.689512  0.765406  0.574822
# 2023-06-29 19:17:38.486  30514.10   0.027736
# 2023-06-29 19:17:39.559  30514.11   0.009320
# 2023-06-29 19:17:42.132  30514.11   0.000000
# 2023-06-29 19:17:43.016  30514.11   0.000000
# 2023-06-29 19:17:46.553  30514.10  -0.002827
# 2023-06-29 19:17:47.398  30514.11   0.011834
# 2023-06-29 19:17:51.605  30514.10  -0.002377
# 2023-06-29 19:17:55.404  30514.10   0.000000
# 2023-06-29 19:17:56.201  30514.10   0.000000

# %%
30518 * 0.003
# Out:
# 91.554

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter()
plt.plot(df['Precio'])

# %%
client.get_account()
# Out:
# {'makerCommission': 0,
#  'takerCommission': 0,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00000000',
#   'taker': '0.00000000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': False,
#  'canDeposit': False,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'updateTime': 1688092858479,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BNB',
#    'free': '1000.00000000',
#    'locked': '0.00000000'},
#   {'asset': 'BTC', 'free': '1.00000000', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '10000.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '100.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '500.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '500000.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '10050.06616159', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '50000.00000000', 'locked': '0.00000000'}],
#  'permissions': ['SPOT']}

# %%
buy_order = client.create_order(
                        symbol='BTCUSDT',
                        side=Client.SIDE_BUY,
                        type=Client.ORDER_TYPE_MARKET,
                        quantity=0.1
                    )

# %%
sell_order = client.create_order(
                            symbol='BNBUSDT',
                            side=Client.SIDE_SELL,
                            type=Client.ORDER_TYPE_MARKET,
                            quantity=0.1
                        )

# %% [markdown]
# ### Separación de tiempo entre señales de compra y de venta y entre ellas mismas.

# %%
with connection.connect() as conn:
    df =conn.execute(text(""" SELECT * FROM "BTCUSDT" """)).mappings().all()
df = pd.DataFrame(df)[['Tiempo', 'Precio']].set_index('Tiempo')
df = df.sort_values(by='Tiempo')
df
# Out:
#                            Precio
# Tiempo
# 2023-06-14 09:12:03.975  25920.01
# 2023-06-14 09:12:05.109  25920.01
# 2023-06-14 09:12:06.210  25920.01
# 2023-06-14 09:12:06.929  25920.01
# 2023-06-14 09:12:07.559  25920.01
# ...                           ...
# 2023-06-30 21:27:44.492  30438.72
# 2023-06-30 21:27:45.617  30436.93
# 2023-06-30 21:27:45.617  30436.93
# 2023-06-30 21:27:46.139  30436.92
# 2023-06-30 21:27:47.581  30436.92
#
# [1224125 rows x 1 columns]

# %%
def ganancias(df):
    MACD(df)
    buy, sell = señal_MACD(df)
    buyprices = df.Precio.iloc[buy]
    sellprices = df.Precio.iloc[sell]
    if sellprices.index[0] < buyprices.index[0]:
        sellprices = sellprices.drop(sellprices.index[0])
    elif buyprices.index[-1] > sellprices.index[-1]:
        buyprices = buyprices.drop(buyprices.index[-1])
    ganancias = []
    for i in range(len(buyprices)):
        ganancias.append((sellprices[i:i+1].item() - buyprices[i:i+1].item()))
    ganancias = pd.DataFrame(ganancias,columns=['ganancia'])
    print(sum(ganancias['ganancia'])*.1)

# %%
ganancias(df)
# Out:
# 5166.807000000049

# %%
MACD(df)

buy, sell = señal_MACD(df)

buyprices = df.Precio.iloc[buy]
sellprices = df.Precio.iloc[sell]

# %%
deltas = []
for i in range(len(df)-1):
    delta = df.index[i+1] - df.index[i]
    deltas.append(delta)

df_deltas = pd.DataFrame(deltas,columns=['deltas'])
df_deltas
# Out:
#                       deltas
# 0     0 days 00:00:00.603000
# 1     0 days 00:00:01.314000
# 2     0 days 00:00:00.526000
# 3     0 days 00:00:04.382000
# 4     0 days 00:00:06.778000
# ...                      ...
# 37716 0 days 00:00:03.231000
# 37717 0 days 00:00:00.731000
# 37718 0 days 00:00:01.602000
# 37719 0 days 00:00:00.478000
# 37720 0 days 00:00:01.081000
#
# [37721 rows x 1 columns]

# %%
df_deltas.describe()
# Out:
#                           deltas
# count                      37721
# mean   0 days 00:00:02.290282654
# std    0 days 00:00:01.971074692
# min       0 days 00:00:00.002000
# 25%       0 days 00:00:00.965000
# 50%       0 days 00:00:01.437000
# 75%       0 days 00:00:03.255000
# max       0 days 00:00:26.295000

# %%
df_deltas[df_deltas['deltas'] >= '0 days 00:00:13.000'].sort_values(by='deltas')
# Out:
#                       deltas
# 10552 0 days 00:00:13.048000
# 21675 0 days 00:00:13.054000
# 5573  0 days 00:00:13.060000
# 6775  0 days 00:00:13.106000
# 9205  0 days 00:00:13.155000
# 241   0 days 00:00:13.214000
# 3578  0 days 00:00:13.230000
# 9510  0 days 00:00:13.242000
# 8900  0 days 00:00:13.313000
# 8952  0 days 00:00:13.317000
# 9026  0 days 00:00:13.343000
# 1575  0 days 00:00:13.364000
# 10138 0 days 00:00:13.458000
# 12558 0 days 00:00:13.551000
# 8562  0 days 00:00:13.567000
# 9668  0 days 00:00:13.575000
# 8361  0 days 00:00:13.579000
# 12576 0 days 00:00:13.607000
# 8805  0 days 00:00:13.755000
# 7903  0 days 00:00:13.756000
# 4355  0 days 00:00:13.779000
# 9376  0 days 00:00:13.829000
# 13589 0 days 00:00:13.878000
# 12741 0 days 00:00:13.960000
# 7225  0 days 00:00:14.017000
# 12171 0 days 00:00:14.048000
# 5686  0 days 00:00:14.092000
# 11165 0 days 00:00:14.413000
# 8587  0 days 00:00:14.414000
# 10023 0 days 00:00:14.480000
# 10179 0 days 00:00:14.609000
# 8969  0 days 00:00:14.668000
# 9350  0 days 00:00:14.790000
# 9918  0 days 00:00:14.798000
# 4517  0 days 00:00:14.914000
# 10899 0 days 00:00:15.073000
# 9321  0 days 00:00:15.099000
# 10047 0 days 00:00:15.733000
# 11203 0 days 00:00:15.797000
# 10016 0 days 00:00:15.895000
# 9385  0 days 00:00:15.931000
# 5774  0 days 00:00:15.992000
# 8033  0 days 00:00:16.039000
# 7084  0 days 00:00:16.576000
# 11401 0 days 00:00:16.602000
# 8161  0 days 00:00:16.916000
# 7329  0 days 00:00:17.080000
# 8886  0 days 00:00:17.210000
# 9373  0 days 00:00:18.111000
# 7702  0 days 00:00:19.045000
# 9344  0 days 00:00:20.235000
# 8829  0 days 00:00:21.251000
# 10209 0 days 00:00:23.729000
# 8232  0 days 00:00:24.961000
# 7482  0 days 00:00:26.295000
