# %%
from binance import Client
import pandas as pd
import os
import numpy as np
from datetime import datetime


## Conexión con Binance para descargar la lista de pares que binance maneja
client = Client()

listacriptos = []
exchange_info = client.get_exchange_info()
for s in exchange_info['symbols']:
    listacriptos.append(s['symbol'])

listacriptos = pd.Series(listacriptos)
usdtpairs = listacriptos[listacriptos.str.contains('USDT')]


## Función para descargar datos y guardarlos en archivos csv

def pull_historical_data(pair,kline_interval):

    file_path = f'D:/proyeto cripto/tradingbot/cristian/scrips/by{kline_interval}/{pair}'
    dir_path = f'D:/proyeto cripto/tradingbot/cristian/scrips/by{kline_interval}/'
    
    if os.path.exists(dir_path):
        pass
    else:
        os.mkdir(dir_path)

    df = pd.DataFrame(client.get_historical_klines(pair,kline_interval,'6 years ago UTC'))
    df = df.iloc[:,:6]
    df.columns = ['Tiempo','Open','High','Low','Close','Volume']
    df['Tiempo'] = pd.to_datetime(df.Tiempo,unit='ms')
    df = df.set_index('Tiempo')
    df = df.astype(float)
    df.to_csv(file_path)


# Se pueden subdividir los análisis temporales a periodos de trading cortos, medianos y largos, cómo lo son los cortos: 1m, 3m, 5m, 15m, 30m, 1h; medianos: 4h, 6h, 8h, 12h, 1D, 1W; 
# largos: 2W, 1M, 3M, 6M, 1Y o más.

## A diferencia del notebook inicial: analisisbasicodegraficas.ipynb... aquí vamos a trabajar con periodos de tiempo más adecuados para 
## hacerlo rápido y comenzar a probar rápido 

for interval in ['1h','4h','6h','8h','12h','1D','1w','1M','3M','6M','1Y']:
    for pair in usdtpairs:  
        print(pair,interval,datetime.now())
        pull_historical_data(pair,interval)

# pull_historical_data('BTCTUSD','1w')
# Out:
# BTCUSDT 1h 2024-03-27 15:25:01.771963
# ETHUSDT 1h 2024-03-27 15:25:47.477436
# BNBUSDT 1h 2024-03-27 15:26:23.110091
# BCCUSDT 1h 2024-03-27 15:26:54.464377
# NEOUSDT 1h 2024-03-27 15:26:57.292218
# LTCUSDT 1h 2024-03-27 15:27:30.388850
# QTUMUSDT 1h 2024-03-27 15:28:03.986177
# ADAUSDT 1h 2024-03-27 15:28:35.701214
# XRPUSDT 1h 2024-03-27 15:29:07.931941
# EOSUSDT 1h 2024-03-27 15:29:39.710866
# TUSDUSDT 1h 2024-03-27 15:30:14.036451
# IOTAUSDT 1h 2024-03-27 15:30:45.175159
# XLMUSDT 1h 2024-03-27 15:31:18.156069
# ONTUSDT 1h 2024-03-27 15:31:51.787123
# TRXUSDT 1h 2024-03-27 15:32:22.351699
# ETCUSDT 1h 2024-03-27 15:32:56.386973
# ICXUSDT 1h 2024-03-27 15:33:26.434524
# VENUSDT 1h 2024-03-27 15:33:59.561566
# NULSUSDT 1h 2024-03-27 15:34:00.061775
# VETUSDT 1h 2024-03-27 15:34:29.749248
# PAXUSDT 1h 2024-03-27 15:35:01.671903
# BCHABCUSDT 1h 2024-03-27 15:35:18.024916
# BCHSVUSDT 1h 2024-03-27 15:35:25.542262
# USDCUSDT 1h 2024-03-27 15:35:28.658607
# LINKUSDT 1h 2024-03-27 15:35:55.093699
# WAVESUSDT 1h 2024-03-27 15:36:24.768164
# BTTUSDT 1h 2024-03-27 15:36:54.199429
# USDSUSDT 1h 2024-03-27 15:37:09.398315
# ONGUSDT 1h 2024-03-27 15:37:15.781250
# HOTUSDT 1h 2024-03-27 15:37:44.795762
# ZILUSDT 1h 2024-03-27 15:38:11.660497
# ZRXUSDT 1h 2024-03-27 15:38:41.842137
# FETUSDT 1h 2024-03-27 15:39:09.094323
# BATUSDT 1h 2024-03-27 15:39:37.056995
# XMRUSDT 1h 2024-03-27 15:40:04.026339
# ZECUSDT 1h 2024-03-27 15:40:33.848708

# %%
from binance import Client
import pandas as pd
import os
import numpy as np
from datetime import datetime


## Conexión con Binance para descargar la lista de pares que binance maneja
client = Client()

listacriptos = []
exchange_info = client.get_exchange_info()
for s in exchange_info['symbols']:
    listacriptos.append(s['symbol'])

listacriptos = pd.Series(listacriptos)
usdtpairs = listacriptos[listacriptos.str.contains('USDT')]


## Función para descargar datos y guardarlos en archivos csv

def pull_historical_data(pair,kline_interval):

    file_path = f'C:/Users/tinma/OneDrive/Escritorio/tradingbot/csvs/historical/by{kline_interval}/{pair}'
    dir_path = f'C:/Users/tinma/OneDrive/Escritorio/tradingbot/csvs/historical/by{kline_interval}'
    
    if os.path.exists(dir_path):
        pass
    else:
        os.mkdir(dir_path)

    df = pd.DataFrame(client.get_historical_klines(pair,kline_interval,'10 years ago UTC'))
    df = df.iloc[:,:6]
    df.columns = ['Tiempo','Open','High','Low','Close','Volume']
    df['Tiempo'] = pd.to_datetime(df.Tiempo,unit='ms')
    df = df.set_index('Tiempo')
    df = df.astype(float)
    df.to_csv(file_path)


# Se pueden subdividir los análisis temporales a periodos de trading cortos, medianos y largos, cómo lo son los cortos: 1m, 3m, 5m, 15m, 30m, 1h; medianos: 4h, 6h, 8h, 12h, 1D, 1W; 
# largos: 2W, 1M, 3M, 6M, 1Y o más.

## A diferencia del notebook inicial: analisisbasicodegraficas.ipynb... aquí vamos a trabajar con periodos de tiempo más adecuados para 
## hacerlo rápido y comenzar a probar rápido 



####################################################################################################
# Con las siguientes líneas corres las funciones y descargas y guardas datos.
####################################################################################################
# for interval in ['1h','4h','6h','8h','12h','1D','1w','1M','3M','6M','1Y']:
#     for pair in usdtpairs:  
#         print(pair,interval,datetime.now())
#         pull_historical_data(pair,interval)

# pull_historical_data('BTCTUSD','1w')

# %%
interval = '3m'
for pair in ['BTCUSDT','ETHUSDT','SOLUSDT','SHIBUSDT','PEPEUSDT','BNBUSDT']:  
    print(pair,interval,datetime.now())
    pull_historical_data(pair,interval)
# Out:
# BTCUSDT 3m 2024-04-03 15:50:23.300830
# ETHUSDT 3m 2024-04-03 16:43:54.562044
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:444, in HTTPResponse._error_catcher(self)
#     443 try:
# --> 444     yield
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\http\client.py:465, in HTTPResponse.read(self, amt)
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1129 if buffer is not None:
# -> 1130     return self._sslobj.read(len, buffer)
#    1131 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     627 while not is_fp_closed(self._fp):
# --> 628     data = self.read(amt=amt, decode_content=decode_content)
#     630     if data:
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:566, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
# --> 566 with self._error_catcher():
#     567     data = self._fp_read(amt) if not fp_closed else b""
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\response.py:449, in HTTPResponse._error_catcher(self)
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
# --> 449     raise ReadTimeoutError(self._pool, None, "Read timed out.")
#     451 except BaseSSLError as e:
#     452     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.binance.com', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In [3], line 4
#       2 for pair in ['BTCUSDT','ETHUSDT','SOLUSDT','SHIBUSDT','PEPEUSDT','BNBUSDT']:
#       3     print(pair,interval,datetime.now())
# ----> 4     pull_historical_data(pair,interval)
#
# Cell In [2], line 32, in pull_historical_data(pair, kline_interval)
#      29 else:
#      30     os.mkdir(dir_path)
# ---> 32 df = pd.DataFrame(client.get_historical_klines(pair,kline_interval,'10 years ago UTC'))
#      33 df = df.iloc[:,:6]
#      34 df.columns = ['Tiempo','Open','High','Low','Close','Volume']
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:984, in Client.get_historical_klines(self, symbol, interval, start_str, end_str, limit, klines_type)
#     964 def get_historical_klines(self, symbol, interval, start_str=None, end_str=None, limit=1000,
#     965                           klines_type: HistoricalKlinesType = HistoricalKlinesType.SPOT):
#     966     """Get Historical Klines from Binance
#     967
#     968     :param symbol: Name of symbol pair e.g. BNBBTC
#    (...)
#     982
#     983     """
# --> 984     return self._historical_klines(
#     985         symbol, interval, start_str=start_str, end_str=end_str, limit=limit, klines_type=klines_type
#     986     )
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:1034, in Client._historical_klines(self, symbol, interval, start_str, end_str, limit, klines_type)
#    1031 idx = 0
#    1032 while True:
#    1033     # fetch the klines from start_ts up to max 500 entries or the end_ts if set
# -> 1034     temp_data = self._klines(
#    1035         klines_type=klines_type,
#    1036         symbol=symbol,
#    1037         interval=interval,
#    1038         limit=limit,
#    1039         startTime=start_ts,
#    1040         endTime=end_ts
#    1041     )
#    1043     # append this loops data to our output data
#    1044     if temp_data:
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:933, in Client._klines(self, klines_type, **params)
#     930     del params['endTime']
#     932 if HistoricalKlinesType.SPOT == klines_type:
# --> 933     return self.get_klines(**params)
#     934 elif HistoricalKlinesType.FUTURES == klines_type:
#     935     return self.futures_klines(**params)
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:918, in Client.get_klines(self, **params)
#     878 def get_klines(self, **params) -> Dict:
#     879     """Kline/candlestick bars for a symbol. Klines are uniquely identified by their open time.
#     880
#     881     https://binance-docs.github.io/apidocs/spot/en/#kline-candlestick-data
#    (...)
#     916
#     917     """
# --> 918     return self._get('klines', data=params, version=self.PRIVATE_API_VERSION)
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:414, in Client._get(self, path, signed, version, **kwargs)
#     413 def _get(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs):
# --> 414     return self._request_api('get', path, signed, version, **kwargs)
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:377, in Client._request_api(self, method, path, signed, version, **kwargs)
#     373 def _request_api(
#     374     self, method, path: str, signed: bool = False, version=BaseClient.PUBLIC_API_VERSION, **kwargs
#     375 ):
#     376     uri = self._create_api_uri(path, signed, version)
# --> 377     return self._request(method, uri, signed, **kwargs)
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\binance\client.py:357, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     353 def _request(self, method, uri: str, signed: bool, force_params: bool = False, **kwargs):
#     355     kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
# --> 357     self.response = getattr(self.session, method)(uri, **kwargs)
#     358     return self._handle_response(self.response)
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File c:\Users\tinma\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:822, in Response.iter_content.<locals>.generate()
#     820     raise ContentDecodingError(e)
#     821 except ReadTimeoutError as e:
# --> 822     raise ConnectionError(e)
#     823 except SSLError as e:
#     824     raise RequestsSSLError(e)
#
# ConnectionError: HTTPSConnectionPool(host='api.binance.com', port=443): Read timed out.
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
interval = '3m'
for pair in ['BTCUSDT','ETHUSDT','SOLUSDT','SHIBUSDT','PEPEUSDT','BNBUSDT']:  
    print(pair,interval,datetime.now())
    pull_historical_data(pair,interval)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 interval = '3m'
#       2 for pair in ['BTCUSDT','ETHUSDT','SOLUSDT','SHIBUSDT','PEPEUSDT','BNBUSDT']:
# ----> 3     print(pair,interval,datetime.now())
#       4     pull_historical_data(pair,interval)
#
# NameError: name 'datetime' is not defined
