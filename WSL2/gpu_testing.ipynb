# %%
# !pip install python-binance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-binance
#   Downloading python_binance-1.0.19-py2.py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 KB 932.0 kB/s eta 0:00:00a 0:00:01
# Collecting ujson
#   Downloading ujson-5.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 KB 3.4 MB/s eta 0:00:00
# Collecting websockets
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 KB 2.3 MB/s eta 0:00:00a 0:00:01
# Collecting pycryptodome
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: aiohttp in /home/tinmarian/.local/lib/python3.10/site-packages (from python-binance) (3.9.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from python-binance) (1.16.0)
# Requirement already satisfied: requests in /home/tinmarian/.local/lib/python3.10/site-packages (from python-binance) (2.31.0)
# Collecting dateparser
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 KB 27.3 MB/s eta 0:00:00
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tinmarian/.local/lib/python3.10/site-packages (from aiohttp->python-binance) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tinmarian/.local/lib/python3.10/site-packages (from aiohttp->python-binance) (1.4.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/tinmarian/.local/lib/python3.10/site-packages (from aiohttp->python-binance) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/tinmarian/.local/lib/python3.10/site-packages (from aiohttp->python-binance) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tinmarian/.local/lib/python3.10/site-packages (from aiohttp->python-binance) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/tinmarian/.local/lib/python3.10/site-packages (from aiohttp->python-binance) (1.9.4)
# Requirement already satisfied: pytz in /home/tinmarian/.local/lib/python3.10/site-packages (from dateparser->python-binance) (2023.3.post1)
# Collecting regex!=2019.02.19,!=2021.8.27
#   Downloading regex-2023.12.25-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.0/774.0 KB 3.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil in /home/tinmarian/.local/lib/python3.10/site-packages (from dateparser->python-binance) (2.8.2)
# Collecting tzlocal
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/tinmarian/.local/lib/python3.10/site-packages (from requests->python-binance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tinmarian/.local/lib/python3.10/site-packages (from requests->python-binance) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tinmarian/.local/lib/python3.10/site-packages (from requests->python-binance) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tinmarian/.local/lib/python3.10/site-packages (from requests->python-binance) (2023.11.17)
# Installing collected packages: websockets, ujson, tzlocal, regex, pycryptodome, dateparser, python-binance
# Successfully installed dateparser-1.2.0 pycryptodome-3.20.0 python-binance-1.0.19 regex-2023.12.25 tzlocal-5.2 ujson-5.9.0 websockets-12.0

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 16.1 MB/s eta 0:00:0000:0100:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tinmarian/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.21 in /home/tinmarian/.local/lib/python3.10/site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: pillow>=8 in /home/tinmarian/.local/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tinmarian/.local/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: packaging>=20.0 in /home/tinmarian/.local/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 13.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.8.4

# %%
import cudf as cf
import pandas as pd
import numpy as np
from datetime import datetime
import scipy as sc
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from binance import Client
from numba import jit
import time
import cupy as cp

client = Client()

# %%
import pandas as pd
recent_data = pd.read_csv('../csvs/historical/by1m/BTCUSDT')
recent_data = recent_data.iloc[:,:6]
recent_data.columns = ['Tiempo','Open','High','Low','Close','Volume']
recent_data['Tiempo'] = recent_data['Tiempo'].astype('datetime64[ns]')# pd.to_datetime(recent_data.Tiempo,unit='ms')
recent_data = recent_data.set_index('Tiempo')
recent_data = recent_data.astype(float)
recent_data = recent_data.reset_index()
recent_data
# Out:
#                      Tiempo      Open      High       Low     Close     Volume
# 0       2017-08-17 04:00:00   4261.48   4261.48   4261.48   4261.48   1.775183
# 1       2017-08-17 04:01:00   4261.48   4261.48   4261.48   4261.48   0.000000
# 2       2017-08-17 04:02:00   4280.56   4280.56   4280.56   4280.56   0.261074
# 3       2017-08-17 04:03:00   4261.48   4261.48   4261.48   4261.48   0.012008
# 4       2017-08-17 04:04:00   4261.48   4261.48   4261.48   4261.48   0.140796
# ...                     ...       ...       ...       ...       ...        ...
# 3473177 2024-03-31 02:09:00  69992.10  69992.10  69992.09  69992.10   1.172140
# 3473178 2024-03-31 02:10:00  69992.10  70019.39  69992.09  70019.38   7.438230
# 3473179 2024-03-31 02:11:00  70019.38  70085.98  70019.38  70082.00  14.504680
# 3473180 2024-03-31 02:12:00  70081.99  70116.24  70081.99  70113.39  18.548410
# 3473181 2024-03-31 02:13:00  70113.39  70117.34  70111.08  70117.33   7.207390
#
# [3473182 rows x 6 columns]
