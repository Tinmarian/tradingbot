# %%
import os

# %%
os.listdir('csvs/historical/by15m')
# Out:
# ['1INCHUSDT',
#  'AAVEUSDT',
#  'ACAUSDT',
#  'ACHUSDT',
#  'ACMUSDT',
#  'ADADOWNUSDT',
#  'ADAUPUSDT',
#  'ADAUSDT',
#  'ADXUSDT',
#  'AERGOUSDT',
#  'AGIXUSDT',
#  'AGLDUSDT',
#  'AKROUSDT',
#  'ALCXUSDT',
#  'ALGOUSDT',
#  'ALICEUSDT',
#  'ALPACAUSDT',
#  'ALPHAUSDT',
#  'ALPINEUSDT',
#  'AMBUSDT',
#  'AMPUSDT',
#  'ANKRUSDT',
#  'ANTUSDT',
#  'APEUSDT',
#  'API3USDT',
#  'APTUSDT',
#  'ARBUSDT',
#  'ARDRUSDT',
#  'ARPAUSDT',
#  'ARUSDT',
#  'ASRUSDT',
#  'ASTRUSDT',
#  'ASTUSDT',
#  'ATAUSDT',
#  'ATMUSDT',
#  'ATOMUSDT',
#  'AUCTIONUSDT',
#  'AUDIOUSDT',
#  'AVAUSDT',
#  'AVAXUSDT',
#  'AXSUSDT',
#  'BADGERUSDT',
#  'BAKEUSDT',
#  'BALUSDT',
#  'BANDUSDT',
#  'BARUSDT',
#  'BATUSDT',
#  'BCHUSDT',
#  'BELUSDT',
#  'BETAUSDT',
#  'BETHUSDT',
#  'BICOUSDT',
#  'BIFIUSDT',
#  'BLZUSDT',
#  'BNBDOWNUSDT',
#  'BNBUPUSDT',
#  'BNBUSDT',
#  'BNTUSDT',
#  'BNXUSDT',
#  'BONDUSDT',
#  'BSWUSDT',
#  'BTCDOWNUSDT',
#  'BTCTUSD',
#  'BTCUPUSDT',
#  'BTCUSDT',
#  'BTSUSDT',
#  'BTTCUSDT',
# ...

# %%
for i in os.listdir('csvs/historical/'):
    for j in os.listdir(f'csvs/historical/{i}'):
        os.rename(f'csvs/historical/{i}/{j}', f'csvs/historical/{i}/{j}.csv')

# %%
for i in os.listdir('csvs/streaming/'):
    os.rename(f'csvs/streaming/{i}', f'csvs/streaming/{i}.csv')
